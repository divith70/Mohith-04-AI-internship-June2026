# %%
# 1-employee id card
name=input("enter the name: ")
age=int(input("enter the age: "))
department=input("enter the department: ")
salary=int(input("enter the salary: "))
print("employee id card")
print("=====================")
print("NAME       : ",name)
print("AGE        : ",age)
print("DEPARTMENT : ",department)
print("SALARY     : ",salary)
print("=====================")
# Out:
# enter the name: MOHITH S
# enter the age: 20
# enter the department: AD
# enter the salary: 600000
# employee id card
# ...
# NAME       :  MOHITH S
# AGE        :  20
# DEPARTMENT :  AD
# SALARY     :  600000
# ...

# %%
# 2-Grocery bill calculator
total=0
for i in range (1,6):
  price=int(input("enter the price: "))
  total=total+price
print("total price: ",total)
# Out:
# enter the price: 60
# enter the price: 46
# enter the price: 10
# enter the price: 95
# enter the price: 100
# total price:  311

# %%
# 3-student percentage
total=0
for i in range (1,6):
  mark=int(input("enter the mark: "))
  total=total+mark
print("total mark: ",total)
percentage=(total/500)*100
print("percentage: ",percentage)
# Out:
# enter the mark: 80
# enter the mark: 48
# enter the mark: 60
# enter the mark: 90
# enter the mark: 100
# total mark:  378
# percentage:  75.6

# %%
# 4-temperature converter
choice=input("enter c to convert from celsius to fahrenheit or f to convert from fahrenheit to celsius: ")
if choice=="c":
  celsius=float(input("enter the temperature in celsius: "))
  fahrenheit=(celsius*9/5)+32
  print("temperature in fahrenheit: ",fahrenheit)
elif choice=="f":
  fahrenheit=float(input("enter the temperature in fahrenheit: "))
  celsius=(fahrenheit-32)*5/9
  print("temperature in celsius: ",celsius)
else:
  print("invalid choice")
# Out:
# enter c to convert from celsius to fahrenheit or f to convert from fahrenheit to celsius: f
# enter the temperature in fahrenheit: 100.4
# temperature in celsius:  38.0

# %%
# 5-mobile recharge calculator
rechargeamount=int(input("enter the amount: "))
gstamount=(rechargeamount*18)/100
totalamount=rechargeamount+gstamount
print("rechargeamount: ",rechargeamount)
print("gstamount: ",gstamount)
print("totalamount: ",totalamount)
# Out:
# enter the amount: 200
# rechargeamount:  200
# gstamount:  36.0
# totalamount:  236.0

# %%
# 6-ATM withdrawal
balance=float(input("enter the balance:"))
withdrawal=float(input("enter the withdrawal amount:"))
if withdrawal <= balance:
  balance -= withdrawal
  print("withdrawal successful")
  print("remaining balance: ",balance)
else:
  print("insufficient balance")
# Out:
# enter the balance:500
# enter the withdrawal amount:500
# withdrawal successful
# remaining balance:  0.0

# %%
# 7-voting eligibility
age=20
if age>=18:
  print("eligible to vote")
else:
  print("not eligible")
# Out:
# eligible to vote

# %%
# 10-elictricty bill
units=int(input("enter the units : "))
if units<=100:
  bill=units*2
elif units<=300:
  bill=(100*2)+(units-100)*4
elif units>300:
  bill=(100*2)+(200*4)+(units-300)*6
  print("bill: ",bill)
# Out:
# enter the units : 600
# bill:  2800

# %%
# 8-online shopping discount
amount=int(input("enter the amount: "))
if amount>=5000:
  discount=amount*0.10
  finalamount=amount-discount
  print("discount: ",discount)
  print("finalamount: ",finalamount)
else:
  print("no discount")
# Out:
# enter the amount: 8000
# discount:  800.0
# finalamount:  7200.0

# %%
# 9-login system
username=input("enter the username: ")
password=input("enter the password: ")
if username=="mohith" and password=="2007":
  print("login successful")
else:
  print("invalid username or password")
# Out:
# enter the username: mohith
# enter the password: 2008
# invalid username or password

# %%
# 11-train ticket booking
age=int(input("enter the age: "))
ticketprice=1000
if age<=12:
  ticketprice= ticketprice-200
  print("ticket price:",ticketprice)
  print("discount for childrens")
elif age>=65:
  ticketprice= ticketprice-300
  print("ticket price:",ticketprice)
  print("discount for senior citizen")
else:
  print("no discount")
# Out:
# enter the age: 10
# ticket price: 800
# discount for childrens

# %%
# 12-blood donation aligibility
age=int(input("enter the age: "))
weight=int(input("enter the weight: "))
if age>=18 :
  if weight>=50:
    print("eligible for blood donation")
  else:
    print("not eligible for blood donation")
else:
  print("not eligible for blood donation")
# Out:
# enter the age: 18
# enter the weight: 51
# eligible for blood donation

# %%
# 13-movi ticket eligibility
age=int(input("enter the age: "))
if age>=18:
  print("eligible for movi ticket")
else:
  print("not eligible for movi ticket")
# Out:
# enter the age: 17
# not eligible for movi ticket

# %%
# 14-loan eligibility
age=int(input("enter the age: "))
salary=int(input("enter the salary: "))
if age>=25:
  if salary>=50000:
    print("eligible for loan")
  else:
    print(" due to less salary you're not eligible for loan")
else:
  print(" you're not eligible for loan")
# Out:
# enter the age: 20
# enter the salary: 20000
#  you're not eligible for loan

# %%
# 15-cab fare distance
distance=float(input("enter the distance: "))
if distance<=5:
  fare=distance*10
  print("fare: ",fare)
elif distance<=10:
  fare=distance*15
  print("fare: ",fare)
else:
  fare=distance*20
print("cab fare :",fare)
# Out:
# enter the distance: 20
# cab fare : 400.0
